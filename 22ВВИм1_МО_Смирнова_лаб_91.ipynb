# %% [markdown]
# 1. Загружаем выборку Iris.csv
# 2. Выводим первый и третий столбцы, сначала по отдельности, потом вместе.
# 3. Вывести 10 первых строк, вывести 23 случайных строк.
# 4. Выводим статистику по числовым показателям
# 5. Сгрупируйте данные по столбцу Setosa

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/gender_classification_v7.csv', delimiter=',')
data.head(5)
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
#вывод 1 столбца
colum_1 = data['long_hair']
colum_1
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 4996    1
# 4997    1
# 4998    1
# 4999    1
# 5000    1
# Name: long_hair, Length: 5001, dtype: int64

# %%
#вывод 3 столбца
colum_3 = data['forehead_height_cm']
colum_3
# Out:
# 0       6.1
# 1       5.4
# 2       6.3
# 3       6.1
# 4       5.9
#        ...
# 4996    5.1
# 4997    5.4
# 4998    5.7
# 4999    6.2
# 5000    5.4
# Name: forehead_height_cm, Length: 5001, dtype: float64

# %%
# вывод 1 и 3 столбца
df=data[['long_hair','forehead_height_cm']]
df
# Out:
#       long_hair  forehead_height_cm
# 0             1                 6.1
# 1             0                 5.4
# 2             0                 6.3
# 3             0                 6.1
# 4             1                 5.9
# ...         ...                 ...
# 4996          1                 5.1
# 4997          1                 5.4
# 4998          1                 5.7
# 4999          1                 6.2
# 5000          1                 5.4
#
# [5001 rows x 2 columns]

# %%
# первые 10 строк
first_10_rows = data[:10]
first_10_rows
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
# 5          1               13.0                 6.8          1          1
# 6          1               15.3                 6.2          1          1
# 7          0               13.0                 5.2          0          0
# 8          1               11.9                 5.4          1          0
# 9          1               12.1                 5.4          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# ...

# %%
# случайные 23 строки
random_23_rows = data.sample(23)
random_23_rows
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 1936          1               12.5                 5.7          0          0
# 2221          1               14.3                 6.1          1          1
# 2071          1               14.6                 6.7          1          1
# 4354          1               12.6                 5.4          0          1
# 791           1               12.3                 5.9          0          0
# 68            1               14.2                 5.8          0          0
# 418           1               12.7                 6.4          1          1
# 717           1               14.7                 7.0          0          0
# 306           1               13.7                 7.1          1          1
# 3013          1               13.6                 6.2          0          1
# 4158          1               11.8                 6.5          0          0
# ...

# %%
# статистика по столбцам с числовыми занчениями
data.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
group=data.groupby('gender')
group.size()
# Out:
# gender
# Female    2501
# Male      2500
# dtype: int64
